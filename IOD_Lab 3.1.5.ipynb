# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 3.1.5
# # *Neo4j and Python*

# %% [markdown]
# ## Introduction
#
# Neo4j is the most popular graph database. Free versions include the Desktop (Developer) edition and the Community Server edition (which we can drive from Python).
#
# We will begin this lab by working through the tutorial embedded in the Neo4j *start* page to learn about graph databases structures and the Cypher query language. We will then see how to integrate a Neo4j database with a Python program.

# %% [markdown]
# The Community Server version can be downloaded here: https://neo4j.com/deployment-center/#releases
# * Link for additional assistance: [How To Neo4j Community Install On Windows 2019 Server For External Access](https://www.youtube.com/watch?v=JaWGwnPkOYA&t=105s)
#
# If installation here is unsuccessful try the Desktop edition: https://neo4j.com/download/
# * Link for additional assistance: [Neo4j (Graph Database) Crash Course](https://www.youtube.com/watch?v=8jNPelugC2s&t=597s)

# %% [markdown]
# - Go through the *Concepts* tutorial.
# - At the end, click *Intro* under *Keep getting started* heading and go through the tutorial.
# - At the end, click *Cypher* under *Keep getting started* heading and go through the tutorial.
# - At the end, click *The Movie Graph* under *Jump into code* heading and go through the tutorial.

# %%
#### (If you are using community)Add instruction to create/connect/start the database from neo4j localhost browser, otherwise your query won't work

# %% [markdown]
# ## Driving Neo4j from Python
#
# There are a variety of Python libraries for Neo4j, some of which provide more compact (and simpler) ways of executing commands. To avoid having to learn too many different ways of doing the same thing, however, we will use the official one, which is based on the syntax of the Cypher query language.

# %% [markdown]
# The ***Neo4j Bolt Driver for Python*** is documented at https://neo4j.com/docs/api/python-driver/current/.

# %%
#!pip install neo4j

# %%
# After a while if you want to use neo4j, you can use this local browser link to log in
# http://localhost:7474/browser/

# %%
#from neo4j.v1 import GraphDatabase
from neo4j import GraphDatabase

#uri = "bolt://localhost:7687" ----> This should also work
uri = "neo4j://localhost:7687"

username = "neo4j"
password = "SuperPassword" #----> your default password might not work in the first try, so you should change your password

# How to change Neo4j default password?
# After going to localhost:7474 in your browser, you will be prompted to log in.
# Use the default login info:
    # User: neo4j
    # Password: neo4j
# You’ll then be asked to change your password.

# %%
driver = GraphDatabase.driver(uri, auth=(username, password))

# %% [markdown]
# To execute a query against a database using this driver, we need to wrap the Cypher query string in a function definition and pass the function to the `read_transaction` method of the `session` object. Our query function then has access to the `tx` object.
#
# Here is a function that finds all the movies that the requested `Person` acted in:

# %%
def print_movies_by(tx, name):
    for record in tx.run("MATCH (a:Person)-[:ACTED_IN]->(anyMovies) "
                         "WHERE a.name = $name "
                         "RETURN anyMovies", name = name):
        print(record["anyMovies"])

# %% [markdown]
# **Note**: For the following queries to work the Movie Graph database should have been loaded with your Neo4j program.

# %% [markdown]
# Here is how to use it to list Tom Hanks' movies:

# %%
with driver.session() as session:
    session.execute_read(print_movies_by, "Tom Hanks")
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 with driver.session() as session:
# ----> 2     session.execute_read(print_movies_by, "Tom Hanks")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/session.py:663, in Session.execute_read(self, transaction_function, *args, **kwargs)
#     594 @NonConcurrentMethodChecker.non_concurrent_method
#     595 def execute_read(
#     596     self,
#    (...)
#     600     *args: _P.args, **kwargs: _P.kwargs
#     601 ) -> _R:
#     602     """Execute a unit of work in a managed read transaction.
#     603
#     604     .. note::
#    (...)
#     661     .. versionadded:: 5.0
#     662     """
# --> 663     return self._run_transaction(
#     664         READ_ACCESS, TelemetryAPI.TX_FUNC,
#     665         transaction_function, args, kwargs
#     666     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/session.py:545, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     543 while True:
#     544     try:
# --> 545         self._open_transaction(
#     546             tx_cls=ManagedTransaction,
#     547             api=None if telemetry_sent else api,
#     548             access_mode=access_mode, metadata=metadata,
#     549             timeout=timeout, api_success_cb=api_success_cb,
#     550         )
#     551         assert isinstance(self._transaction, ManagedTransaction)
#     552         tx = self._transaction
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/session.py:424, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     413 def _open_transaction(
#     414     self,
#     415     *,
#    (...)
#     422     api_success_cb: t.Optional[t.Callable[[dict], None]] = None,
#     423 ) -> None:
# --> 424     self._connect(access_mode=access_mode)
#     425     assert self._connection is not None
#     426     if api is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:165, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     157     else:
#     158         # This is the first time we open a connection to a server in a
#     159         # cluster environment for this session without explicitly
#    (...)
#     162         # we shall use this database explicitly for all subsequent
#     163         # actions within this session.
#     164         log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 165         self._pool.update_routing_table(
#     166             database=self._config.database,
#     167             imp_user=self._config.impersonated_user,
#     168             bookmarks=self._get_bookmarks(),
#     169             auth=auth,
#     170             acquisition_timeout=acquisition_timeout,
#     171             database_callback=self._set_cached_database
#     172         )
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:774, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     769 prefer_initial_routing_address = \
#     770     self.routing_tables[database].initialized_without_writers
#     772 if prefer_initial_routing_address:
#     773     # TODO: Test this state
# --> 774     if self._update_routing_table_from(
#     775         self.address, database=database,
#     776         imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     777         acquisition_timeout=acquisition_timeout,
#     778         database_callback=database_callback
#     779     ):
#     780         # Why is only the first initial routing address used?
#     781         return
#     782 if self._update_routing_table_from(
#     783     *(existing_routers - {self.address}), database=database,
#     784     imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     785     acquisition_timeout=acquisition_timeout,
#     786     database_callback=database_callback
#     787 ):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:720, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     716 for router in routers:
#     717     for address in NetworkUtil.resolve_address(
#     718         router, resolver=self.pool_config.resolver
#     719     ):
# --> 720         new_routing_table = self.fetch_routing_table(
#     721             address=address, acquisition_timeout=acquisition_timeout,
#     722             database=database, imp_user=imp_user, bookmarks=bookmarks,
#     723             auth=auth
#     724         )
#     725         if new_routing_table is not None:
#     726             new_database = new_routing_table.database
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:657, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth)
#     655 new_routing_info = None
#     656 try:
# --> 657     new_routing_info = self.fetch_routing_info(
#     658         address, database, imp_user, bookmarks, auth,
#     659         acquisition_timeout
#     660     )
#     661 except Neo4jError as e:
#     662     # checks if the code is an error that is caused by the client. In
#     663     # this case there is no sense in trying to fetch a RT from another
#     664     # router. Hence, the driver should fail fast during discovery.
#     665     if e._is_fatal_during_discovery():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:625, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     623     auth = copy(auth)
#     624     auth.force_auth = False
# --> 625 cx = self._acquire(address, auth, deadline, None)
#     626 try:
#     627     routing_table = cx.route(
#     628         database=database or self.workspace_config.database,
#     629         imp_user=imp_user or self.workspace_config.impersonated_user,
#     630         bookmarks=bookmarks
#     631     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:557, in Neo4jPool.open.<locals>.opener(addr, auth_manager, deadline)
#     556 def opener(addr, auth_manager, deadline):
# --> 557     return Bolt.open(
#     558         addr, auth_manager=auth_manager, deadline=deadline,
#     559         routing_context=routing_context, pool_config=pool_config
#     560     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:488, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     486 connection.socket.set_deadline(deadline)
#     487 try:
# --> 488     connection.hello()
#     489 finally:
#     490     connection.socket.set_deadline(None)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_bolt5.py:574, in Bolt5x2.hello(self, dehydration_hooks, hydration_hooks)
#     572 self.logon(dehydration_hooks, hydration_hooks)
#     573 self.send_all()
# --> 574 self.fetch_all()
#     575 check_supported_server_product(self.server_info.agent)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:864, in Bolt.fetch_all(self)
#     862 response = self.responses[0]
#     863 while not response.complete:
# --> 864     detail_delta, summary_delta = self.fetch_message()
#     865     detail_count += detail_delta
#     866     summary_count += summary_delta
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:850, in Bolt.fetch_message(self)
#     846 # Receive exactly one message
#     847 tag, fields = self.inbox.pop(
#     848     hydration_hooks=self.responses[0].hydration_hooks
#     849 )
# --> 850 res = self._process_message(tag, fields)
#     851 self.idle_since = monotonic()
#     852 return res
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_bolt5.py:369, in Bolt5x0._process_message(self, tag, fields)
#     367 self._server_state_manager.state = self.bolt_states.FAILED
#     368 try:
# --> 369     response.on_failure(summary_metadata or {})
#     370 except (ServiceUnavailable, DatabaseUnavailable):
#     371     if self.pool:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:281, in LogonResponse.on_failure(self, metadata)
#     279 handler = self.handlers.get("on_summary")
#     280 Util.callback(handler)
# --> 281 raise Neo4jError.hydrate(**metadata)
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}

# %% [markdown]
# Clearly, some further wrangling is required to produce neat output. (Read the documentation before you attempt this.)

# %% [markdown]
# In fact, both the method of using the Neo4j Bolt Driver and the data returned by it are unwieldy. This is typical of low-level drivers.

# %% [markdown]
# Try building and running some more queries based on the code in examples queries in The Movie Graph tutorial.

# %%
# Prints a more readable output
def print_movies_by(tx, name):
    for record in tx.run("MATCH (a:Person)-[:ACTED_IN]->(movie:Movie) "
                         "WHERE a.name = $name "
                         "RETURN movie.title AS title, movie.tagline AS tagline, movie.released AS released", name=name):
        title = record["title"]
        tagline = record["tagline"]
        released = record["released"]
        print(f"Title: {title}")
        print(f"Tagline: {tagline}")
        print(f"Released: {released}")
        print("=" * 50)

with driver.session() as session:
    session.execute_read(print_movies_by, "Tom Hanks")
# Out:
# Title: Apollo 13
# Tagline: Houston, we have a problem.
# Released: 1995
# ==================================================
# Title: You've Got Mail
# Tagline: At odds in life... in love on-line.
# Released: 1998
# ==================================================
# Title: A League of Their Own
# Tagline: Once in a lifetime you get a chance to do something different.
# Released: 1992
# ==================================================
# Title: Joe Versus the Volcano
# Tagline: A story of love, lava and burning desire.
# Released: 1990
# ==================================================
# Title: That Thing You Do
# Tagline: In every life there comes a time when that thing you dream becomes that thing you do
# Released: 1996
# ==================================================
# Title: The Da Vinci Code
# Tagline: Break The Codes
# Released: 2006
# ==================================================
# Title: Cloud Atlas
# Tagline: Everything is connected
# Released: 2012
# ==================================================
# Title: Cast Away
# Tagline: At the edge of the world, his journey begins.
# Released: 2000
# ==================================================
# Title: The Green Mile
# Tagline: Walk a mile you'll never forget.
# Released: 1999
# ==================================================
# Title: Sleepless in Seattle
# Tagline: What if someone you never met, someone you never saw, someone you never knew was the only someone for you?
# Released: 1993
# ==================================================
# Title: The Polar Express
# Tagline: This Holiday Season... Believe
# Released: 2004
# ==================================================
# Title: Charlie Wilson's War
# Tagline: A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.
# Released: 2007
# ==================================================

# %% [markdown]
# ## 1. Find actors who have acted in more than a certain number of movies:

# %%
def find_actors_with_movies(tx, threshold):
    query = (
        "MATCH (a:Person)-[:ACTED_IN]->(m:Movie) "
        "WITH a, count(m) AS movieCount "
        "WHERE movieCount > $threshold "
        "RETURN a.name AS actorName, movieCount"
    )
    result = tx.run(query, threshold=threshold)
    for record in result:
        print(record["actorName"], "acted in", record["movieCount"], "movies")

# %%
# Usage:
driver = GraphDatabase.driver("bolt://localhost:7687", auth=(username, password))
with driver.session() as session:
    session.execute_read(find_actors_with_movies, threshold=5)
# Out:
# Keanu Reeves acted in 7 movies
# Tom Hanks acted in 12 movies

# %% [markdown]
# ## 2. Identify co-actors of a specific actor

# %%
def find_co_actors(tx, actor_name):
    query = (
        "MATCH (a1:Person)-[:ACTED_IN]->(m:Movie)<-[:ACTED_IN]-(a2:Person) "
        "WHERE a1.name = $actorName "
        "RETURN a2.name AS coActorName, collect(m.title) AS movies"
    )
    result = tx.run(query, actorName=actor_name)
    data = [(record["coActorName"], ", ".join(record["movies"])) for record in result]
    return data

# %%
from tabulate import tabulate
# Usage:
# driver = GraphDatabase.driver("bolt://localhost:7687", auth=(username, password))
with driver.session() as session:
    data = session.execute_read(???)

print(tabulate(data, headers=["Co-Actor Name", "Movies"]))
# Out:
# Co-Actor Name           Movies
# ----------------------  -------------------------------------------------------------
# Ed Harris               Apollo 13
# Gary Sinise             Apollo 13, The Green Mile
# Kevin Bacon             Apollo 13
# Bill Paxton             Apollo 13, A League of Their Own
# Parker Posey            You've Got Mail
# Greg Kinnear            You've Got Mail
# Meg Ryan                You've Got Mail, Joe Versus the Volcano, Sleepless in Seattle
# Steve Zahn              You've Got Mail
# Dave Chappelle          You've Got Mail
# Madonna                 A League of Their Own
# Rosie O'Donnell         A League of Their Own, Sleepless in Seattle
# Geena Davis             A League of Their Own
# Lori Petty              A League of Their Own
# Nathan Lane             Joe Versus the Volcano
# Liv Tyler               That Thing You Do
# Charlize Theron         That Thing You Do
# Ian McKellen            The Da Vinci Code
# Audrey Tautou           The Da Vinci Code
# Paul Bettany            The Da Vinci Code
# Jim Broadbent           Cloud Atlas
# Halle Berry             Cloud Atlas
# Hugo Weaving            Cloud Atlas
# Helen Hunt              Cast Away
# Sam Rockwell            The Green Mile
# Bonnie Hunt             The Green Mile
# Patricia Clarkson       The Green Mile
# James Cromwell          The Green Mile
# Michael Clarke Duncan   The Green Mile
# David Morse             The Green Mile
# Victor Garber           Sleepless in Seattle
# Bill Pullman            Sleepless in Seattle
# Rita Wilson             Sleepless in Seattle
# Julia Roberts           Charlie Wilson's War
# Philip Seymour Hoffman  Charlie Wilson's War

# %% [markdown]
# ## 3. Find movies released after a certain year:

# %%
def find_movies_after_year(tx, year):
    query = (
        "MATCH (m:Movie) "
        "WHERE m.released > $year "
        "RETURN m.title AS movieTitle, m.released AS releaseYear"
    )
    result = tx.run(query, year=year)
    for record in result:
        print(record["movieTitle"], "was released in", record["releaseYear"])

# %%
# Usage:
#driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))
with driver.session() as session:
    ???
# Out:
# The Matrix Reloaded was released in 2003
# The Matrix Revolutions was released in 2003
# Something's Gotta Give was released in 2003
# The Polar Express was released in 2004
# RescueDawn was released in 2006
# The Da Vinci Code was released in 2006
# V for Vendetta was released in 2006
# Charlie Wilson's War was released in 2007
# Speed Racer was released in 2008
# Frost/Nixon was released in 2008
# Ninja Assassin was released in 2009
# Cloud Atlas was released in 2012

# %% [markdown]
# ## 4. Find movies in a particular genre:

# %%
def find_movies_in_genre(tx, genre):
    query = (
        "MATCH ???"
        "WHERE g.name = $genre "
        "RETURN m.title AS movieTitle"
    )
    result = tx.run(query, genre=genre)
    for record in result:
        print(record["movieTitle"], "is in the", genre, "genre")

# %%
with driver.session() as session:
    session.execute_read(find_movies_in_genre, genre="Action")

# %% [markdown]
# ## 5. Find movies directed by a specific director:

# %%
def find_movies_by_director(tx, director):
    query = (
        "MATCH ???"
        "WHERE d.name = $director "
        "RETURN m.title AS movieTitle"
    )
    result = tx.run(query, director=director)
    for record in result:
        print(record["movieTitle"], "was directed by", director)

# %%
# Usage:
#driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))
with driver.session() as session:
    session.execute_read(find_movies_by_director, director="Steven Spielberg")

# %% [markdown]
# ## 6. Find movies where a specific actor both acted in and directed:

# %%
def find_movies_actor_directed(tx, actor_name):
    query = (
        "MATCH ???"
        "WHERE a.name = $actorName "
        "RETURN m.title AS movieTitle"
    )
    result = tx.run(query, actorName=actor_name)
    for record in result:

        print(actor_name, "acted in and directed", record["movieTitle"])

# %%
# Usage:
#driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))
with driver.session() as session:
    session.execute_read(find_movies_actor_directed, actor_name="Tom Hanks")
# Out:
# Tom Hanks acted in and directed That Thing You Do

# %% [markdown]
# ## 7. Find actors who have worked in a specific genre:

# %%
def find_actors_in_genre(tx, genre):
    query = (
        "MATCH ???"
        "WHERE g.name = $genre "
        "RETURN DISTINCT a.name AS actorName"
    )
    result = tx.run(query, genre=genre)
    for record in result:
        print(record["actorName"], "has worked in the", genre, "genre")

# %%
# Usage:
#driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))
with driver.session() as session:
    session.execute_read(find_actors_in_genre, genre="Comedy")

# %%
session.close()
driver.close()

# %% [markdown]
# ### Additional Reference
# * [Build applications with Neo4j and Python](https://neo4j.com/docs/python-manual/current/)

# %% [markdown]
# ## - END -

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
